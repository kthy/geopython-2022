# %% [markdown]
# # GeoPython 2022 - Introduction to `dask-geopandas`
#
# **Martin Fleischmann, Joris van den Bossche**
#
# 22/06/2022, Basel
#
# ## Setup
#
# Follow the Readme to set-up the environment correctly. You should have these packages installed:
#
# ```
# - geopandas
# - dask-geopandas
# - pyogrio
# - pyarrow
# - python-graphviz
# - esda
# - dask-labextension # optionally, if using JupyterLab
# ```

# %% [markdown]
# ## GeoPandas refresh
#
# Let's start with a quick refresh of GeoPandas.
#
# ### What is GeoPandas?
#
# **Easy, fast and scalable geospatial analysis in Python**
#
# From the docs:
#
# > The goal of GeoPandas is to make working with geospatial data in python easier. It combines the capabilities of pandas and shapely, providing geospatial operations in pandas and a high-level interface to multiple geometries to shapely. GeoPandas enables you to easily do operations in python that would otherwise require a spatial database such as PostGIS.
#
# A quick demo:

# %%
import geopandas
# Out:
# /home/kristian/.local/share/virtualenvs/02-dask-scaling-m1lwLOq8/lib/python3.10/site-packages/geopandas/_compat.py:112: UserWarning: The Shapely GEOS version (3.10.2-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %% [markdown]
# GeoPandas includes some built-in data, we can use them as an illustration.

# %%
path = geopandas.datasets.get_path("naturalearth_lowres")
path
# Out:
# '/home/kristian/.local/share/virtualenvs/02-dask-scaling-m1lwLOq8/lib/python3.10/site-packages/geopandas/datasets/naturalearth_lowres/naturalearth_lowres.shp'

# %%
world = geopandas.read_file(path)
world.head()
# Out:
#        pop_est      continent                      name iso_a3  gdp_md_est  \
# 0     889953.0        Oceania                      Fiji    FJI        5496
# 1   58005463.0         Africa                  Tanzania    TZA       63177
# 2     603253.0         Africa                 W. Sahara    ESH         907
# 3   37589262.0  North America                    Canada    CAN     1736425
# 4  328239523.0  North America  United States of America    USA    21433226
#
#                                             geometry
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...

# %% [markdown]
# For the sake of simplicity here, we can remove Antarctica and re-project the data to the EPSG 3857, which will not complain about measuring the area (but never use EPSG 3857 to measure the actual area as it is extremely skewed).

# %%
world = world.query("continent != 'Antarctica'").to_crs(3857)

# %% [markdown]
# GeoPandas GeoDataFrame can carry one or more geometry columns and brings the support of geospatial operations on these columns. Like a creation of a convex hull.

# %%
world['convex_hull'] = world.convex_hull

# %% [markdown]
# This is equal to the code above as GeoPandas exposes geometry methods of the active geometry column to the GeoDataFrame level:

# %%
world['convex_hull'] = world.geometry.convex_hull

# %% [markdown]
# Now you can see that we have two geometry columns stored in our `world` GeoDataFrame but only the original one is treated as an _active_ geometry (that is the one accessible directly, without getting the column first).

# %%
world.head()
# Out:
#        pop_est      continent                      name iso_a3  gdp_md_est  \
# 0     889953.0        Oceania                      Fiji    FJI        5496
# 1   58005463.0         Africa                  Tanzania    TZA       63177
# 2     603253.0         Africa                 W. Sahara    ESH         907
# 3   37589262.0  North America                    Canada    CAN     1736425
# 4  328239523.0  North America  United States of America    USA    21433226
#
#                                             geometry  \
# 0  MULTIPOLYGON (((20037508.343 -1812498.413, 200...
# 1  POLYGON ((3774143.866 -105758.362, 3792946.708...
# 2  POLYGON ((-964649.018 3205725.605, -964597.245...
# 3  MULTIPOLYGON (((-13674486.249 6274861.394, -13...
# 4  MULTIPOLYGON (((-13674486.249 6274861.394, -13...
#
#                                          convex_hull
# 0  POLYGON ((19807373.107 -2071284.965, -20037508...
# 1  POLYGON ((4064728.977 -1313965.660, 3847200.38...
# 2  POLYGON ((-1899491.585 2391849.029, -1894705.4...
# 3  POLYGON ((-9205018.632 5112435.324, -13805051....
# 4  POLYGON ((-17331127.807 2145071.126, -17358788...

# %% [markdown]
# We can also plot the results. Both Russia and Fiji are a bit weird as they cross the anti-meridian.

# %%
ax = world.plot(figsize=(12, 12))
world.convex_hull.plot(ax=ax, facecolor='none', edgecolor='black')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## What is Dask
#
# From the docs:
#
# > Dask provides advanced parallelism and distributed out-of-core computation with a dask.dataframe module designed to scale pandas. Since GeoPandas is an extension to the pandas DataFrame, the same way Dask scales pandas can also be applied to GeoPandas.
#
# We will cover the high-level API of Dask. For more, see the [Dask tutorial](https://tutorial.dask.org).
#
# Let's import `numpy` and `pandas` for a comparison and three high-level Dask modules - `bag`, `array`, and `dataframe`.

# %%
import numpy as np
import pandas as pd

import dask.dataframe as dd
import dask.array as da
import dask.bag as db

# %% [markdown]
# Before we explore those, let's introduce the dask `Client` as it will allow us to see how dask manages all its tasks.
#
# Here we create a Client on top of a local (automatically created) cluster with 4 workers (the laptop we use has 4 performance cores).

# %%
from dask.distributed import Client

client = Client(n_workers=4)
# Out:
# 2022-06-22 12:05:57,211 - distributed.diskutils - INFO - Found stale lock file and directory '/home/kristian/src/geopython-2022/02-dask-scaling/dask-worker-space/worker-5kz6824r', purging
# 2022-06-22 12:05:57,211 - distributed.diskutils - INFO - Found stale lock file and directory '/home/kristian/src/geopython-2022/02-dask-scaling/dask-worker-space/worker-_54nvmsg', purging
# 2022-06-22 12:05:57,211 - distributed.diskutils - INFO - Found stale lock file and directory '/home/kristian/src/geopython-2022/02-dask-scaling/dask-worker-space/worker-h7fso76b', purging
# 2022-06-22 12:05:57,211 - distributed.diskutils - INFO - Found stale lock file and directory '/home/kristian/src/geopython-2022/02-dask-scaling/dask-worker-space/worker-w24ttuib', purging

# %%
client
# Out:
# <Client: 'tcp://127.0.0.1:38047' processes=4 threads=16, memory=49.99 GiB>

# %% [markdown]
# We can open the Dask dashboard to watch what is happenning in real-time using the link above, in the Client details. But if you have a [JupyterLab extension for Dask](https://github.com/dask/dask-labextension), you can watch different components directly from the JupyterLab interface.

# %% [markdown]
# ### dask.bag
#
# With the Client and cluster in place, we can properly explore Dask. Let's start with a `dask.bag`, the simplest of the objects. You can imagine it as a distributed list.

# %%
b = db.from_sequence([1, 2, 3, 4, 5, 6, 2, 1], npartitions=2)
b
# Out:
# dask.bag<from_sequence, npartitions=2>

# %% [markdown]
# Now, note that when we try to call `b`, we don't see its contents.
#
# Let's check what happens with `sum`.

# %%
b.sum()

# %% [markdown]
# Again, we don't see the answer, but some abstract `Item` object instead. That is because Dask usually runs all the operations lazily and waits for a `compute` call before it does the actual computation.
#
# Instead, it plans what it should do and create a task graph. That looks like this:

# %%
b.sum().visualize()

# %% [markdown]
# We can see individual partitions (rectangles), operations (circles), and movement of data between partitions.
#
# When we call `compute`, this task graph is executed and Dask returns the expected value.

# %%
b.sum().compute()
# Out:
# 24

# %% [markdown]
# ### dask.array
#
# Let's move onto an array. Where bag is partitioned along 1 dimension (the sequence is essentially cut into pieces), array is like a numpy array split along both dimension. In practice, each of the partitions is a numpy array and dask array combines them together. Each partition can be then processed separately.

# %%
data = np.arange(100_000).reshape(200, 500)
a = da.from_array(data, chunks=(100, 100))
a
# Out:
# dask.array<array, shape=(200, 500), dtype=int64, chunksize=(100, 100), chunktype=numpy.ndarray>

# %% [markdown]
# We see some dimensions, dtypes and sizes here but not the data. Beacause again, all is done lazily.

# %%
a[:50, 200]
# Out:
# dask.array<getitem, shape=(50,), dtype=int64, chunksize=(50,), chunktype=numpy.ndarray>

# %% [markdown]
# Even indexing requires `compute` to return values, otherwised it still give a dask array.

# %%
a[:50, 200].compute()
# Out:
# array([  200,   700,  1200,  1700,  2200,  2700,  3200,  3700,  4200,
#         4700,  5200,  5700,  6200,  6700,  7200,  7700,  8200,  8700,
#         9200,  9700, 10200, 10700, 11200, 11700, 12200, 12700, 13200,
#        13700, 14200, 14700, 15200, 15700, 16200, 16700, 17200, 17700,
#        18200, 18700, 19200, 19700, 20200, 20700, 21200, 21700, 22200,
#        22700, 23200, 23700, 24200, 24700])

# %% [markdown]
# Simlarly for `mean`.

# %%
a.mean().compute()
# Out:
# 49999.5

# %% [markdown]
# Since the mean is not super straightforward to parallelise (you can't just do mean in partitions and then mean of that), we can check how dask implements its logic.

# %%
a.mean().visualize()

# %% [markdown]
# Quite complex, right? Let's compare it to the indexing we did before.

# %%
a[:50, 200].visualize()

# %% [markdown]
# You can see that dask efficiently accesses only that one partition it needs at this moment.

# %% [markdown]
# ### dask.dataframe
#
# Finally, we move to the parallelised DataFrame. It mirrors the logic of the array implementation, with a difference that individual partitions are pandas.DataFrames and partitioning happens along a single axis (rows).
#
# Dask.dataframe tries to mirror the pandas API. The same approach as we will later see with dask-geopandas.

# %%
df = pd.read_csv("data/airports.csv")
df.head()
# Out:
#        id ident           type                                name  \
# 0    6523   00A       heliport                   Total Rf Heliport
# 1  323361  00AA  small_airport                Aero B Ranch Airport
# 2    6524  00AK  small_airport                        Lowell Field
# 3    6525  00AL  small_airport                        Epps Airpark
# 4    6526  00AR         closed  Newport Hospital & Clinic Heliport
#
#    latitude_deg  longitude_deg  elevation_ft
# 0     40.070801     -74.933601          11.0
# 1     38.704022    -101.473911        3435.0
# 2     59.947733    -151.692524         450.0
# 3     34.864799     -86.770302         820.0
# 4     35.608700     -91.254898         237.0

# %% [markdown]
# In this specific case (`head()`), dask actually reads those 5 rows and shows them but that tends to be an exception, likely because it is a very cheap operation.

# %%
df = dd.read_csv("data/airports.csv")
df.head()
# Out:
#        id ident           type                                name  \
# 0    6523   00A       heliport                   Total Rf Heliport
# 1  323361  00AA  small_airport                Aero B Ranch Airport
# 2    6524  00AK  small_airport                        Lowell Field
# 3    6525  00AL  small_airport                        Epps Airpark
# 4    6526  00AR         closed  Newport Hospital & Clinic Heliport
#
#    latitude_deg  longitude_deg  elevation_ft
# 0     40.070801     -74.933601          11.0
# 1     38.704022    -101.473911        3435.0
# 2     59.947733    -151.692524         450.0
# 3     34.864799     -86.770302         820.0
# 4     35.608700     -91.254898         237.0

# %% [markdown]
# If you try to show the whole DataFrame, you get a placeholder that tells you how many partitions you have, which columns and what are their dtypes.

# %%
df
# Out:
# Dask DataFrame Structure:
#                   id   ident    type    name latitude_deg longitude_deg elevation_ft
# npartitions=1
#                int64  object  object  object      float64       float64      float64
#                  ...     ...     ...     ...          ...           ...          ...
# Dask Name: read-csv, 1 tasks

# %% [markdown]
# Since the `airports.csv` is a single file on disk, dask gives us a single partion. But when we have more of them, typically one per month or a country, we can read each as a partition.

# %%
df = dd.read_csv("data/airports_csv/*.csv")
df
# Out:
# Dask DataFrame Structure:
#                   id   ident    type    name latitude_deg longitude_deg elevation_ft
# npartitions=4
#                int64  object  object  object      float64       float64      float64
#                  ...     ...     ...     ...          ...           ...          ...
#                  ...     ...     ...     ...          ...           ...          ...
#                  ...     ...     ...     ...          ...           ...          ...
#                  ...     ...     ...     ...          ...           ...          ...
# Dask Name: read-csv, 4 tasks

# %% [markdown]
# As before, all the computation is done lazily. Take a look at the computation of mean elevation.

# %%
elevation = df.elevation_ft.mean()
elevation
# Out:
# dd.Scalar<series-..., dtype=float64>

# %% [markdown]
# We get a dask Scalar object here but as before, we don't get the value until we call `compute()`.

# %%
elevation.compute()
# Out:
# 1294.776494472499

# %% [markdown]
# You can probably notice the similarity of the graph with the one calculating mean over an array.

# %%
elevation.visualize()

# %% [markdown]
# We can also quickly compare it to a task graph for something easier, like a sum.

# %%
df.elevation_ft.sum().visualize()

# %% [markdown]
# Not that it makes much sense to compute a sum of elevations, but we can do that and if you're checking the dashboard, you'll notice very little communication as the task is easy to parallelise and we need to gather the results only in the final step.

# %%
df.elevation_ft.sum().compute()
# Out:
# 75894619.0

# %% [markdown]
# ## Dask-GeoPandas
#
# Dask-GeoPandas follows exactly the same model as `dask.dataframe` adopted for scaling `pandas.DataFrame`. We have a single `dask_geopandas.GeoDataFrame`, composed of individual partitions where each is a `geopandas.GeoDataFrame`.

# %%
import dask_geopandas

# %% [markdown]
# ## Create dask GeoDataFrame
#
# We have a plenty of options how to build a `dask_geopandas.GeoDataFrame`. From in-memory `geopandas.GeoDataFrame`, reading the GIS file (using pyogrio under the hood), reading GeoParquet or Feather, or from dask.dataframe.

# %%
world_ddf = dask_geopandas.from_geopandas(world, npartitions=4)
world_ddf
# Out:
# Dask GeoDataFrame Structure:
#                pop_est continent    name  iso_a3 gdp_md_est  geometry convex_hull
# npartitions=4
# 0              float64    object  object  object      int64  geometry    geometry
# 44                 ...       ...     ...     ...        ...       ...         ...
# 88                 ...       ...     ...     ...        ...       ...         ...
# 132                ...       ...     ...     ...        ...       ...         ...
# 176                ...       ...     ...     ...        ...       ...         ...
# Dask Name: from_pandas, 4 tasks

# %%
world_ddf_file = dask_geopandas.read_file(path, npartitions=4)
world_ddf_file
# Out:
# Dask GeoDataFrame Structure:
#                pop_est continent    name  iso_a3 gdp_md_est  geometry
# npartitions=4
# 0              float64    object  object  object      int64  geometry
# 45                 ...       ...     ...     ...        ...       ...
# 90                 ...       ...     ...     ...        ...       ...
# 135                ...       ...     ...     ...        ...       ...
# 176                ...       ...     ...     ...        ...       ...
# Dask Name: read-file, 4 tasks

# %% [markdown]
# ### Partitioned IO
#
# Since we are working with individual partitions, it is useful to save the dataframe already partitioned. The ideal file format for that is a GeoParquet.

# %%
world_ddf.to_parquet("world/")
# Out:
# /home/kristian/.local/share/virtualenvs/02-dask-scaling-m1lwLOq8/lib/python3.10/site-packages/geopandas/_compat.py:112: UserWarning: The Shapely GEOS version (3.10.2-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(
# /home/kristian/.local/share/virtualenvs/02-dask-scaling-m1lwLOq8/lib/python3.10/site-packages/geopandas/_compat.py:112: UserWarning: The Shapely GEOS version (3.10.2-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(
# /home/kristian/.local/share/virtualenvs/02-dask-scaling-m1lwLOq8/lib/python3.10/site-packages/geopandas/_compat.py:112: UserWarning: The Shapely GEOS version (3.10.2-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(
# /home/kristian/.local/share/virtualenvs/02-dask-scaling-m1lwLOq8/lib/python3.10/site-packages/geopandas/_compat.py:112: UserWarning: The Shapely GEOS version (3.10.2-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %% [markdown]
# For more complex tasks, we recommend using Parquet IO as an intermediate step to avoid large task graphs.

# %%
world_ddf = dask_geopandas.read_parquet("world/")
world_ddf
# Out:
# Dask GeoDataFrame Structure:
#                pop_est continent    name  iso_a3 gdp_md_est  geometry convex_hull
# npartitions=4
#                float64    object  object  object      int64  geometry    geometry
#                    ...       ...     ...     ...        ...       ...         ...
#                    ...       ...     ...     ...        ...       ...         ...
#                    ...       ...     ...     ...        ...       ...         ...
#                    ...       ...     ...     ...        ...       ...         ...
# Dask Name: read-parquet, 4 tasks

# %% [markdown]
# ## Embarrassingly parallel computation
#
# The first type of operations where you can benefit from parallelisation is so-called embarrassingly parallel computation. That is a computation where we treat individual partitions or individual rows indenpendently of the other, meaning there is no inter-worker communication and no data need to be sent elsewhere.
#
# One example of that is a calculation of area.

# %%
area = world_ddf.area
area.visualize()

# %% [markdown]
# Similar one, this time returing a `dask_geopandas.GeoSeries` instead of a `dask.dataframe.Series` would be a `convex_hull` method.

# %%
convex_hull = world_ddf.convex_hull
convex_hull.visualize()

# %% [markdown]
# Since both are creating a series, we can assing both as individual columns. Let's see how that changes the task graph.

# %%
world_ddf['area'] = world_ddf.area
world_ddf['convex_hull'] = world_ddf.convex_hull
world_ddf.visualize()

# %% [markdown]
# Finally, we can call `compute()` and get all the results.

# %%
r = world_ddf.compute()
r
# Out:
#          pop_est      continent                      name iso_a3  gdp_md_est  \
# 0       889953.0        Oceania                      Fiji    FJI        5496
# 1     58005463.0         Africa                  Tanzania    TZA       63177
# 2       603253.0         Africa                 W. Sahara    ESH         907
# 3     37589262.0  North America                    Canada    CAN     1736425
# 4    328239523.0  North America  United States of America    USA    21433226
# ..           ...            ...                       ...    ...         ...
# 172    6944975.0         Europe                    Serbia    SRB       51475
# 173     622137.0         Europe                Montenegro    MNE        5542
# 174    1794248.0         Europe                    Kosovo    KOS        7926
# 175    1394973.0  North America       Trinidad and Tobago    TTO       24269
# 176   11062113.0         Africa                  S. Sudan    SSD       11998
#
#                                               geometry  \
# 0    MULTIPOLYGON (((20037508.343 -1812498.413, 200...
# 1    POLYGON ((3774143.866 -105758.362, 3792946.708...
# 2    POLYGON ((-964649.018 3205725.605, -964597.245...
# 3    MULTIPOLYGON (((-13674486.249 6274861.394, -13...
# 4    MULTIPOLYGON (((-13674486.249 6274861.394, -13...
# ..                                                 ...
# 172  POLYGON ((2096126.508 5765757.958, 2096127.988...
# 173  POLYGON ((2234260.104 5249565.284, 2204305.520...
# 174  POLYGON ((2292095.761 5139344.949, 2284604.344...
# 175  POLYGON ((-6866186.192 1204901.071, -6802177.4...
# 176  POLYGON ((3432408.751 390883.649, 3334408.389 ...
#
#                                            convex_hull          area
# 0    POLYGON ((19807373.107 -2071284.965, -20037508...  2.128334e+10
# 1    POLYGON ((4064728.977 -1313965.660, 3847200.38...  9.522552e+11
# 2    POLYGON ((-1899491.585 2391849.029, -1894705.4...  1.171023e+11
# 3    POLYGON ((-9205018.632 5112435.324, -13805051....  5.216648e+13
# 4    POLYGON ((-17331127.807 2145071.126, -17358788...  2.186228e+13
# ..                                                 ...           ...
# 172  POLYGON ((2401900.131 5197783.944, 2255063.490...  1.488818e+11
# 173  POLYGON ((2156455.368 5142654.741, 2133155.290...  2.497975e+10
# 174  POLYGON ((2306240.400 5138104.706, 2292095.761...  2.072802e+10
# 175  POLYGON ((-6876204.946 1118889.975, -6896242.4...  8.051555e+09
# 176  POLYGON ((3432408.751 390883.649, 3114716.820 ...  6.399394e+11
#
# [176 rows x 8 columns]

# %% [markdown]
# ## Spatial join
#
# If you have to deal with a large dataframes and need a spatial join, dask-geopandas can help. Let's try to illustrate the logic of spatial join on the partitioned data using the locations of airports from around the world.

# %%
airports = pd.read_csv("data/airports.csv")
airports.head()
# Out:
#        id ident           type                                name  \
# 0    6523   00A       heliport                   Total Rf Heliport
# 1  323361  00AA  small_airport                Aero B Ranch Airport
# 2    6524  00AK  small_airport                        Lowell Field
# 3    6525  00AL  small_airport                        Epps Airpark
# 4    6526  00AR         closed  Newport Hospital & Clinic Heliport
#
#    latitude_deg  longitude_deg  elevation_ft
# 0     40.070801     -74.933601          11.0
# 1     38.704022    -101.473911        3435.0
# 2     59.947733    -151.692524         450.0
# 3     34.864799     -86.770302         820.0
# 4     35.608700     -91.254898         237.0

# %% [markdown]
# The data comes as a CSV, so we first need to create a GeoDataFrame.

# %%
airports = geopandas.GeoDataFrame(
    airports,
    geometry=geopandas.GeoSeries.from_xy(
        airports["longitude_deg"],
        airports["latitude_deg"],
        crs=4326,
    )
)

# %% [markdown]
# And from that, we can create a partitioned `dask_geopandas.GeoDataFrame`. Note that we could also read the CSV with dask.dataframe and create a GeoDataFrame from that using the `dask_geopandas.from_dask_dataframe` function and `dask_geopandas.points_from_xy` to create the geometry. But since it all comfortably fits in memory, we can pick whichever option we like.

# %%
airports_ddf = dask_geopandas.from_geopandas(
    airports,
    npartitions=12
)

# %% [markdown]
# We will join the point data of airports with the `naturalearth_lowres` dataset we have stored as an already partitioned parquet.

# %%
world_ddf = dask_geopandas.read_parquet("data/world/")
world_ddf
# Out:
# Dask GeoDataFrame Structure:
#               pop_est continent    name  iso_a3 gdp_md_est  geometry convex_hull
# npartitions=4
#                 int64    object  object  object    float64  geometry    geometry
#                   ...       ...     ...     ...        ...       ...         ...
#                   ...       ...     ...     ...        ...       ...         ...
#                   ...       ...     ...     ...        ...       ...         ...
#                   ...       ...     ...     ...        ...       ...         ...
# Dask Name: read-parquet, 4 tasks

# %% [markdown]
# The API of the `sjoin` is exactly the same as you know it from geopandas. Just in this case, it currently only creates a task graph.

# %%
joined = airports_ddf.sjoin(world_ddf, predicate="within")

# %% [markdown]
# We started from 12 partitions of `airports_ddf` and 4 partitions of `world_ddf`. Since we haven't told Dask how are these partitions spatially distributed, it just plans to do the join of each partition from one dataframe to each partition form the other one. 12x4 = 48 partitions in the end. We can easily check that with the `npartitions` attribute.

# %%
joined.npartitions
# Out:
# 48

# %% [markdown]
# The whole logic can also be represented by a task graph that illustates the inefficiency of such an approach.

# %%
joined.visualize()

# %% [markdown]
# ## Spatial partitioning
#
# Luckily, dask-geopandas supports spatial partitioning. It means that it can calculate the spatial extent of each partition (as the overall convex hull of the partition) and use it internally to do smarter decisions when creating the task graph.
#
# But first, we need to calculate these paritions. This operation is done eagerly and involves immediate reading of all geometries.

# %%
airports_ddf.calculate_spatial_partitions()

# %% [markdown]
# The resulting `spatial_partitions` attribute is a `geopandas.GeoSeries`.

# %%
airports_ddf.spatial_partitions
# Out:
# 0     POLYGON ((169.85200 11.22200, -155.97835 19.83...
# 1     POLYGON ((-1.00000 -89.98944, -41.03330 -77.65...
# 2     POLYGON ((106.84825 -78.46614, -67.75550 -54.6...
# 3     POLYGON ((-25.51644 -75.56741, -71.56667 -74.8...
# 4     POLYGON ((-36.50950 -54.28240, -155.57840 19.1...
# 5     POLYGON ((139.27850 -24.33880, -157.19466 1.76...
# 6     POLYGON ((146.39617 -41.23519, -70.64390 -38.0...
# 7     POLYGON ((0.00000 -90.00000, -176.20348 -44.29...
# 8     POLYGON ((-81.39478 -80.31420, -83.32083 -79.7...
# 9     POLYGON ((70.22033 -49.35033, -56.16673 -34.86...
# 10    POLYGON ((-155.67730 18.91630, -159.74431 21.9...
# 11    POLYGON ((111.52361 -66.69083, -171.43511 -14....
# dtype: geometry

# %%
airports_ddf.spatial_partitions.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_00d62621177a11f28b1837af6942257d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_00d62621177a11f28b1837af6942257d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_00d62621177a11f28b1837af6942257d = L.map(
#                 &quot;map_00d62621177a11f28b1837af6942257d&quot;,
#                 {
#                     center: [-3.625, 0.04935049999998853],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_00d62621177a11f28b1837af6942257d);
#
#
#
#
#
#             var tile_layer_9a765bc8cd32a82986b661c782214068 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_00d62621177a11f28b1837af6942257d);
#
#
#             map_00d62621177a11f28b1837af6942257d.fitBounds(
#                 [[-90.0, -179.876999], [82.75, 179.9757]],
#                 {}
#             );
#
#
#         function geo_json_b97b45ee204fc3b41514a96704453e0f_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_b97b45ee204fc3b41514a96704453e0f_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_b97b45ee204fc3b41514a96704453e0f_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_b97b45ee204fc3b41514a96704453e0f_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_b97b45ee204fc3b41514a96704453e0f_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_b97b45ee204fc3b41514a96704453e0f.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_b97b45ee204fc3b41514a96704453e0f_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_b97b45ee204fc3b41514a96704453e0f = L.geoJson(null, {
#                 onEachFeature: geo_json_b97b45ee204fc3b41514a96704453e0f_onEachFeature,
#
#                 style: geo_json_b97b45ee204fc3b41514a96704453e0f_styler,
#                 pointToLayer: geo_json_b97b45ee204fc3b41514a96704453e0f_pointToLayer
#         });
#
#         function geo_json_b97b45ee204fc3b41514a96704453e0f_add (data) {
#             geo_json_b97b45ee204fc3b41514a96704453e0f
#                 .addData(data)
#                 .addTo(map_00d62621177a11f28b1837af6942257d);
#         }
#             geo_json_b97b45ee204fc3b41514a96704453e0f_add({&quot;bbox&quot;: [-179.876999, -90.0, 179.9757, 82.75], &quot;features&quot;: [{&quot;bbox&quot;: [-166.1320037841797, 11.222, 169.852005, 70.49220275878906], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[169.852005, 11.222], [-155.978347, 19.832881], [-157.94789, 21.35839], [-166.1320037841797, 64.83170318603516], [-161.907151, 70.293545], [-148.69500732421875, 70.49220275878906], [169.852005, 11.222]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-167.48599243164062, -89.989444, 179.275997, 70.911118], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-1.0, -89.989444], [-41.0333, -77.650008], [-68.1269931793, -67.5669411575], [-156.97007, 21.079367], [-167.48599243164062, 65.63870239257812], [-154.407037, 70.715599], [-153.237766, 70.911118], [179.275997, 51.381504], [164.03539, -74.739373], [-1.0, -89.989444]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-158.134994507, -78.466139, 177.368, 82.75], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[106.84825, -78.466139], [-67.7555, -54.63158], [-70.87, -53.1315], [-157.713887, 21.370833], [-158.134994507, 61.8679008484], [-140.81, 69.62], [-119.3216, 76.2392],

# %% [markdown]
# As you can see from the plot above, our partitions are not very homogenous in terms of their spatial distribution. Each contains points from nearly whole world. And that does not help with simplification of a task graph.

# %% [markdown]
# ### The goal
#
# We need our partitions to be spatially coherent to minimise the amount of inter-worker communication. So we have to find a way of reshuffling the data in between workers.
#
# ### Hilbert curve
#
# One way of doing so is to follow the Hilbert space-filling curve, which is a 2-dimensional curve like the one below along which we can map our geometries (usually points). The distance along the Hilbert curve then represents a spatial proximity. Two points with a similar Hilbert distance are therefore ensured to be close in space.
#
# ![Hilbert](fig/Hilbert-curve_rounded-gradient-animated.gif)
#
# (Animation by Tim Sauder, https://en.wikipedia.org/wiki/Hilbert_curve#/media/File:Hilbert-curve_rounded-gradient-animated.gif)
#
# `dask-geopandas` (as of 0.1.0) implements Hilbert curve and two other methods based on a similar concept of space-filling (Morton curve and Geohash). You can either compute them directly or let `dask-geopandas` use them under the hood in a `spatial_shuffle` method that computes the distance along the curve and uses it to reshuffle the dataframe into spatially homogenous chunks. (Note that geometries are abstracted to the midpoint of their bounding box for the purpose of measuring the distance along the curve.)

# %%
hilbert_distance = airports_ddf.hilbert_distance()
hilbert_distance
# Out:
# Dask Series Structure:
# npartitions=12
# 0        uint32
# 6031        ...
#           ...
# 66341       ...
# 72362       ...
# Name: hilbert_distance, dtype: uint32
# Dask Name: hilbert_distance, 24 tasks

# %%
hilbert_distance.compute()
# Out:
# 0        1626125973
# 1        1254176125
# 2        1388750304
# 3        1970081721
# 4        1251544672
#             ...
# 72358    2477592609
# 72359    3541124831
# 72360    1249251466
# 72361    1460340716
# 72362    3025967453
# Name: hilbert_distance, Length: 72363, dtype: uint32

# %% [markdown]
# `spatial_shuffle` uses by default `hilbert_distance` and partitions the dataframe based on this Series.

# %%
airports_ddf = airports_ddf.spatial_shuffle()

# %% [markdown]
# We can now check how the new partitions look like in space.

# %%
airports_ddf.spatial_partitions.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b2133ae616dae21cb9d52de8e2c2a641 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b2133ae616dae21cb9d52de8e2c2a641&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_b2133ae616dae21cb9d52de8e2c2a641 = L.map(
#                 &quot;map_b2133ae616dae21cb9d52de8e2c2a641&quot;,
#                 {
#                     center: [-3.625, 0.04935049999998853],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_b2133ae616dae21cb9d52de8e2c2a641);
#
#
#
#
#
#             var tile_layer_248282da8830130fb3a821902f7d6cf6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b2133ae616dae21cb9d52de8e2c2a641);
#
#
#             map_b2133ae616dae21cb9d52de8e2c2a641.fitBounds(
#                 [[-90.0, -179.876999], [82.75, 179.9757]],
#                 {}
#             );
#
#
#         function geo_json_66ba803fb509b81325e821d9664df440_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_66ba803fb509b81325e821d9664df440_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_66ba803fb509b81325e821d9664df440_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_66ba803fb509b81325e821d9664df440_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_66ba803fb509b81325e821d9664df440_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_66ba803fb509b81325e821d9664df440.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_66ba803fb509b81325e821d9664df440_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_66ba803fb509b81325e821d9664df440 = L.geoJson(null, {
#                 onEachFeature: geo_json_66ba803fb509b81325e821d9664df440_onEachFeature,
#
#                 style: geo_json_66ba803fb509b81325e821d9664df440_styler,
#                 pointToLayer: geo_json_66ba803fb509b81325e821d9664df440_pointToLayer
#         });
#
#         function geo_json_66ba803fb509b81325e821d9664df440_add (data) {
#             geo_json_66ba803fb509b81325e821d9664df440
#                 .addData(data)
#                 .addTo(map_b2133ae616dae21cb9d52de8e2c2a641);
#         }
#             geo_json_66ba803fb509b81325e821d9664df440_add({&quot;bbox&quot;: [-179.876999, -90.0, 179.9757, 82.75], &quot;features&quot;: [{&quot;bbox&quot;: [-83.320833, -90.0, 0.0, -3.623912], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[0.0, -90.0], [-1.0, -89.989444], [-81.39478, -80.3142], [-83.320833, -79.777778], [-80.09619903564453, -26.29389953613281], [-66.43299865722656, -3.9670000076293945], [-61.662656, -3.710721], [-48.823726, -3.657594], [-38.733047, -3.623912], [-32.423302, -3.854471], [-14.3937, -7.9696], [-5.645943, -15.957725], [0.0, -90.0]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-179.876999, -44.293167, -44.936943, 34.160078], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-176.203476, -44.293167], [-176.46514, -43.81189], [-179.876999, -16.690599], [-176.615705, 0.809797], [-169.533997, 16.7286], [-112.097137, 34.108451], [-111.726665, 34.160078], [-103.41000366210938, 34.14550018310547], [-101.42291, 34.13113], [-101.21976, 34.09282], [-44.936943, -17.438334], [-44.941453, -21.194765], [-44.969133, -22.574043], [-45.074057, -23.440628], [-45.309205, -23.908788], [-47.924935, -25.007831], [-176.203476, -44.293167]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&

# %% [markdown]
# When we are reading parquet file, its metadata already contain the information on the extent of each partition and we therefore don't have to calculate them by reading all the geometries. We can quickly check that.

# %%
world_ddf.spatial_partitions is not None
# Out:
# True

# %% [markdown]
# The world dataset has known partitions but is not spatially shuffled.

# %%
world_ddf.spatial_partitions.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c99b732bc60b0142d382a16db02b9675 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c99b732bc60b0142d382a16db02b9675&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_c99b732bc60b0142d382a16db02b9675 = L.map(
#                 &quot;map_c99b732bc60b0142d382a16db02b9675&quot;,
#                 {
#                     center: [14.01665000000001, 1.4210854715202004e-14],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_c99b732bc60b0142d382a16db02b9675);
#
#
#
#
#
#             var tile_layer_8d6891ff5ae7bcfbbd02b330f17dec9e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c99b732bc60b0142d382a16db02b9675);
#
#
#             map_c99b732bc60b0142d382a16db02b9675.fitBounds(
#                 [[-55.61182999999999, -180.0], [83.64513000000001, 180.00000000000003]],
#                 {}
#             );
#
#
#         function geo_json_a0c8997050fd0a2ffd2a341ef50dd2e6_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_a0c8997050fd0a2ffd2a341ef50dd2e6_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_a0c8997050fd0a2ffd2a341ef50dd2e6_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_a0c8997050fd0a2ffd2a341ef50dd2e6_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_a0c8997050fd0a2ffd2a341ef50dd2e6_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_a0c8997050fd0a2ffd2a341ef50dd2e6.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_a0c8997050fd0a2ffd2a341ef50dd2e6_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_a0c8997050fd0a2ffd2a341ef50dd2e6 = L.geoJson(null, {
#                 onEachFeature: geo_json_a0c8997050fd0a2ffd2a341ef50dd2e6_onEachFeature,
#
#                 style: geo_json_a0c8997050fd0a2ffd2a341ef50dd2e6_styler,
#                 pointToLayer: geo_json_a0c8997050fd0a2ffd2a341ef50dd2e6_pointToLayer
#         });
#
#         function geo_json_a0c8997050fd0a2ffd2a341ef50dd2e6_add (data) {
#             geo_json_a0c8997050fd0a2ffd2a341ef50dd2e6
#                 .addData(data)
#                 .addTo(map_c99b732bc60b0142d382a16db02b9675);
#         }
#             geo_json_a0c8997050fd0a2ffd2a341ef50dd2e6_add({&quot;bbox&quot;: [-180.0, -55.61182999999999, 180.00000000000003, 83.64513000000001], &quot;features&quot;: [{&quot;bbox&quot;: [-180.0, -55.61182999999999, 180.00000000000003, 83.64513000000001], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[180.00000000000003, -55.61182999999999], [180.00000000000003, 83.64513000000001], [-180.0, 83.64513000000001], [-180.0, -55.61182999999999], [180.00000000000003, -55.61182999999999]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-84.9749110582731, -29.045461928017282, 56.396847365144, 37.38526357680575], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[56.396847365144, -29.045461928017282], [56.396847365144, 37.38526357680575], [-84.9749110582731, 37.38526357680575], [-84.9749110582731, -29.045461928017282], [56.396847365144, -29.045461928017282]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-9.526570603869715, -16.597849623279988, 167.84487674384505, 69.10624726020087], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[167.84487674384505, -16.597849623279988], [167.84487674384505, 69.10624726020087], [-9.526570603869715, 69.106247

# %% [markdown]
# Even without doing that, we can already see that the resulting number of partitions is now 32, instead of 48 as some of the joins that would result in an empty dataframe are simply filtered out.

# %%
joined = airports_ddf.sjoin(world_ddf, predicate="within")

# %%
joined.npartitions
# Out:
# 33

# %%
# %%time
joined.compute()
# Out:
# CPU times: user 277 ms, sys: 52.5 ms, total: 330 ms
# Wall time: 785 ms
#                       id    ident            type  \
# hilbert_distance
# 801122366          41113     SE16   small_airport
# 801144915           6083     SETM   small_airport
# 801352465          41595  EC-0001   small_airport
# 1880303520          2066     DAOE   small_airport
# 1880352370          2071     DAOO  medium_airport
# ...                  ...      ...             ...
# 3278400869        342012  VU-0002          closed
# 3278411657        342011  VU-0001          closed
# 3278684342         32056     NVSP   small_airport
# 3278853651         35162     NVSX   small_airport
# 3278857863         31847     NVSL   small_airport
#
#                                                    name_left  latitude_deg  \
# hilbert_distance
# 801122366                                       Loja Airport     -3.881424
# 801144915                      Camilo Ponce Enriquez Airport     -3.995890
# 801352465                                    Carabon Airport     -3.628550
# 1880303520                                  Bou Sfer Airport     35.735401
# 1880352370        Oran International Airport Ahmed Ben Bella     35.623901
# ...                                                      ...           ...
# 3278400869                               Luganville Airfield    -15.515500
# 3278411657                               Turtle Bay Airfield    -15.377557
# 3278684342                                    Norsup Airport    -16.079700
# 3278853651                             Southwest Bay Airport    -16.486400
# 3278857863                                     Lamap Airport    -16.461123
#
#                   longitude_deg  elevation_ft                     geometry  \
# hilbert_distance
# 801122366            -79.234749        7684.0   POINT (-79.23475 -3.88142)
# 801144915            -79.371902        4056.0   POINT (-79.37190 -3.99589)
# 801352465            -80.187798         126.0   POINT (-80.18780 -3.62855)
# 1880303520            -0.805389         187.0    POINT (-0.80539 35.73540)
# 1880352370            -0.621183         295.0    POINT (-0.62118 35.62390)
# ...                         ...           ...                          ...
# 3278400869           167.131900         484.0  POINT (167.13190 -15.51550)
# 3278411657           167.179473          58.0  POINT (167.17947 -15.37756)
# 3278684342           167.401001          23.0  POINT (167.40100 -16.07970)
# 3278853651           167.447200          68.0  POINT (167.44720 -16.48640)
# 3278857863           167.829253           7.0  POINT (167.82925 -16.46112)
#
#                   index_right   pop_est      continent name_right iso_a3  \
# hilbert_distance
# 801122366                  44  16290913  South America    Ecuador    ECU
# 801144915                  44  16290913  South America    Ecuador    ECU
# 801352465                  44  16290913  South America    Ecuador    ECU
# 1880303520                 82  40969443         Africa    Algeria    DZA
# 1880352370                 82  40969443         Africa    Algeria    DZA
# ...                       ...       ...            ...        ...    ...
# 3278400869                 89    282814        Oceania    Vanuatu    VUT
# 3278411657                 89    282814        Oceania    Vanuatu    VUT
# 3278684342                 89    282814        Oceania    Vanuatu    VUT
# 3278853651                 89    282814        Oceania    Vanuatu    VUT
# 3278857863                 89    282814        Oceania    Vanuatu    VUT
#
#                   gdp_md_est  \
# hilbert_distance
# 801122366           182400.0
# 801144915           182400.0
# 801352465           182400.0
# 1880303520          609400.0
# 1880352370          609400.0
# ...                      ...
# 3278400869             723.0
# 3278411657             723.0
# 3278684342             723.0
# 3278853651             723.0
# 3278857863             723.0
#
#                                                         convex_hull
# hilbert_distance
# 801122366         POLYGON ((-8817092.447 -552738.227, -8954789.4...
# 801144915         POLYGON ((-8817092.447 -552738.227, -8954789.4...
# 801352465         POLYGON ((-8817092.447 -552738.227, -8954789.4...
# 1880303520        POLYGON ((351561.777 2161690.786, -966742.962 ...
# 1880352370        POLYGON ((351561.777 2161690.786, -966742.962 ...
# ...                                                             ...
# 3278400869        POLYGON ((18647704.661 -1874062.146, 18567329....
# 3278411657        POLYGON ((18647704.661 -1874062.146, 18567329....
# 3278684342        POLYGON ((18647704.661 -1874062.146, 18567329....
# 3278853651        POLYGON ((18647704.661 -1874062.146, 18567329....
# 3278857863        POLYGON ((18647704.661 -1874062.146, 18567329....
#
# [68303 rows x 15 columns]

# %% [markdown]
# ### What about a larger problem?
#
# Dropping down from 48 to 32 partitions doesn't sound like a big deal. But you usually want to use dask-geopandas to tackle a bit larger problems. To simulate one, We can load a GADM dataset containd detailed administrative boundaries of the whole world (around 2GB GPKG) and join our airport data to that.
#
# _Note that this dataset is not part of the repository so you will not be able to run these two cells._

# %%
gadm_ddf = dask_geopandas.read_file('data/gadm404.gpkg', npartitions=64)
joined = airports_ddf.sjoin(gadm_ddf, predicate="within")
joined.npartitions
# Out:
# ERROR 4: data/gadm404.gpkg: No such file or directory
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File ~/.local/share/virtualenvs/02-dask-scaling-m1lwLOq8/lib/python3.10/site-packages/pyogrio/_io.pyx:135, in pyogrio._io.ogr_open()
#
# File ~/.local/share/virtualenvs/02-dask-scaling-m1lwLOq8/lib/python3.10/site-packages/pyogrio/_err.pyx:177, in pyogrio._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: data/gadm404.gpkg: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DataSourceError                           Traceback (most recent call last)
# Input In [61], in <cell line: 1>()
# ----> 1 gadm_ddf = dask_geopandas.read_file('data/gadm404.gpkg', npartitions=64)
#       2 joined = airports_ddf.sjoin(gadm_ddf, predicate="within")
#       3 joined.npartitions
#
# File ~/.local/share/virtualenvs/02-dask-scaling-m1lwLOq8/lib/python3.10/site-packages/dask_geopandas/io/file.py:103, in read_file(path, npartitions, chunksize, layer, columns, **kwargs)
#     100 if kwargs:
#     101     raise ValueError("Additional pyogrio keywords are not yet supported")
# --> 103 total_size = pyogrio.read_info(path, layer=layer)["features"]
#     105 if chunksize is None:
#     106     chunksize = int(ceil(total_size / npartitions))
#
# File ~/.local/share/virtualenvs/02-dask-scaling-m1lwLOq8/lib/python3.10/site-packages/pyogrio/core.py:175, in read_info(path_or_buffer, layer, encoding)
#     172 path, buffer = get_vsi_path(path_or_buffer)
#     174 try:
# --> 175     result = ogr_read_info(path, layer=layer, encoding=encoding)
#     176 finally:
#     177     if buffer is not None:
#
# File ~/.local/share/virtualenvs/02-dask-scaling-m1lwLOq8/lib/python3.10/site-packages/pyogrio/_io.pyx:982, in pyogrio._io.ogr_read_info()
#
# File ~/.local/share/virtualenvs/02-dask-scaling-m1lwLOq8/lib/python3.10/site-packages/pyogrio/_io.pyx:144, in pyogrio._io.ogr_open()
#
# DataSourceError: data/gadm404.gpkg: No such file or directory

# %% [markdown]
# Without any spatial sorting of the GADM dataset, we have to do 12*64 joins.
#
# But we can load the same dataset that has been spatially sorted.

# %%
gadm_sorted = dask_geopandas.read_parquet("data/gadm_spatial/")
joined = airports_ddf.sjoin(gadm_sorted, predicate="within")
joined.npartitions

# %% [markdown]
# The resulting number of partitions is 151, filtering out more than 80% of spatial joins that no longer need to be done.

# %% [markdown]
# ## Aggregations with dissolve
#
# Dissolve is a typical operation when you usually need to do some shuffling of data between workers to ensure that all observations within the same category (specified using the `by` keyword) end up in the same partition so they can actually be dissolved into a single polygon. As you can imagine, proper spatial partitions may help as well but in this case, they help only in the computation, not in the task graph.
#
# Let's have a look at an example.

# %%
world_ddf = dask_geopandas.read_parquet("data/world/")

continents = world_ddf.dissolve('continent', split_out=6)
continents
# Out:
# Dask GeoDataFrame Structure:
#               pop_est    name  iso_a3 gdp_md_est convex_hull  geometry
# npartitions=6
#                 int64  object  object    float64    geometry  geometry
#                   ...     ...     ...        ...         ...       ...
# ...               ...     ...     ...        ...         ...       ...
#                   ...     ...     ...        ...         ...       ...
#                   ...     ...     ...        ...         ...       ...
# Dask Name: set_crs, 48 tasks

# %% [markdown]
# Above, we are using the API we know from GeoPandas with one new keyword - `split_out`. That specifies into how many partitions should we send the dissolved result. The whole method is based on the `groupby`, exactly as the original one, which returns a single partition by default. We rarely want that to happen.

# %%
continents.visualize()

# %% [markdown]
# The task graph shows exactly what happens. Since Dask doesn't know which categories are where, it designs the task graph to move potentially shuffle data from every original partition to every new one. In reality, some of these will be empty. And the better spatial partitions we have, the more of them will be empty, hence our operation will be cheaper.

# %% [markdown]
# ## Custom functions with `map_partitions`
#
# Not every function you may need is built-in and you often need to apply a custom one to the partitioned dataframe. The most common way of doing that is the `map_partitions` method.
#
# The typical use case is below. We want to describe the shape of each polygon using the `shape_index` from the `esda` package. With geopandas, it would look like this.

# %%
from esda.shape import shape_index

world['shape_idx'] = shape_index(world)
world.explore('shape_idx')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fc8789d834efb0deb59930f748f56e97 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fc8789d834efb0deb59930f748f56e97&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_fc8789d834efb0deb59930f748f56e97 = L.map(
#                 &quot;map_fc8789d834efb0deb59930f748f56e97&quot;,
#                 {
#                     center: [14.01665000000001, 1.4210854715202004e-14],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_fc8789d834efb0deb59930f748f56e97);
#
#
#
#
#
#             var tile_layer_799a55857cb385afa4a248c1d67b1139 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fc8789d834efb0deb59930f748f56e97);
#
#
#             map_fc8789d834efb0deb59930f748f56e97.fitBounds(
#                 [[-55.61182999999999, -180.0], [83.64513000000001, 180.00000000000003]],
#                 {}
#             );
#
#
#         function geo_json_9a90b718f9fe07958168b012e4d9c9f9_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;:
#                     return {&quot;color&quot;: &quot;#440154&quot;, &quot;fillColor&quot;: &quot;#440154&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;: case &quot;30&quot;: case &quot;164&quot;:
#                     return {&quot;color&quot;: &quot;#a8db34&quot;, &quot;fillColor&quot;: &quot;#a8db34&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;:
#                     return {&quot;color&quot;: &quot;#2d718e&quot;, &quot;fillColor&quot;: &quot;#2d718e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;: case &quot;20&quot;: case &quot;79&quot;: case &quot;106&quot;:
#                     return {&quot;color&quot;: &quot;#4ac16d&quot;, &quot;fillColor&quot;: &quot;#4ac16d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;: case &quot;12&quot;: case &quot;136&quot;:
#                     return {&quot;color&quot;: &quot;#21918c&quot;, &quot;fillColor&quot;: &quot;#21918c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;: case &quot;31&quot;: case &quot;104&quot;: case &quot;150&quot;:
#                     return {&quot;color&quot;: &quot;#54c568&quot;, &quot;fillColor&quot;: &quot;#54c568&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;6&quot;: case &quot;123&quot;:
#                     return {&quot;color&quot;: &quot;#24aa83&quot;, &quot;fillColor&quot;: &quot;#24aa83&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;7&quot;:
#                     return {&quot;color&quot;: &quot;#1f968b&quot;, &quot;fillColor&quot;: &quot;#1f968b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8&quot;:
#                     return {&quot;color&quot;: &quot;#30698e&quot;, &quot;fillColor&quot;: &quot;#30698e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;9&quot;: case &quot;33&quot;: case &quot;154&quot;:
#                     return {&quot;color&quot;: &quot;#1fa188&quot;, &quot;fillColor&quot;: &quot;#1fa188&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;10&quot;:
#                     return {&quot;color&quot;: &quot;#365d8d&quot;, &quot;fillColor&quot;: &quot;#365d8d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;11&quot;: case &quot;35&quot;: case &quot;145&quot;:
#                     return {&quot;color&quot;: &quot;#90d743&quot;, &quot;fillColor&quot;: &quot;#90d743&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;13&quot;: case &quot;163&quot;: case &quot;166&quot;:
#                     return {&quot;color&quot;: &quot;#9dd93b&quot;, &quot;fillColor&quot;: &quot;#9dd93b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;14&quot;: case &quot;121&quot;:
#                     return {&quot;color&quot;: &quot;#bddf26&quot;, &quot;fillColor&quot;: &quot;#bd

# %% [markdown]
# But when you try to use the same code with a `dask_geopandas.GeoDataFrame`, it will not work.

# %%
# THIS WILL FAIL
world_ddf = dask_geopandas.read_parquet("world/")
world_ddf['shape_idx'] = shape_index(world_ddf)

# %% [markdown]
# In fact, it doesn't even give us a meaningful error message. Simply, because `esda` does not expect `dask_geopandas.GeoDataFrame` here, but expects `geopandas.GeoDataFrame` or some form of an in-memory array of geometries. Then it returns an array of floats.
#
# In this case, we can use `map_partitions` to _map_ the `shape_index()` function across individual partitions. A dummy code would look something like this:
#
# ```py
# results = []
#
# for partition in ddf:
#     results.append(shape_index(partition))
# ```
#
# The actual code is of course not a loop like this but principle is the same. We take each partition and apply the function.

# %%
world_ddf = dask_geopandas.read_parquet("world/")
shape_idx = world_ddf.map_partitions(shape_index)

# %% [markdown]
# The resulting task graph is the same as we have seen before in simple cases of embarrasingly parralel computation. `map_partitions` will always be embarrasingly parralel.

# %%
shape_idx.visualize()

# %%
r = shape_idx.compute()

# %% [markdown]
# ### Custom function
#
# We can also write our custom functions to be used with `map_partitions`. The only rule is that everything needs to happen within a single GeoDataFrame, i.e. within a single partition independently of the other. But we don't need to return a new column but we can also return a single value for each partition. Like a sum of area covered by polygons in each partition.

# %%
def my_fn(gdf):
    """get a sum of area covered by polygons in a gdf
    
    Parameters
    ----------
    gdf : GeoDataFrame
    
    Returns
    -------
    float
    
    """
    area = gdf.geometry.area
    return sum(area)

# %% [markdown]
# We cannot assign this as a new column as we did above, but we also don't need it.

# %%
world_ddf.map_partitions(my_fn).compute()
# Out:
# 0    2.404711e+14
# 1    1.883620e+13
# 2    2.622637e+13
# 3    4.235641e+13
# dtype: float64

# %% [markdown]
# The task graph is the same as before, even though we return only a single value per partition.

# %%
world_ddf.map_partitions(my_fn).visualize()

# %% [markdown]
# If you want to assign the result as a new column of your dataframe, you need to ensure you return an array or a Series of the correct length.

# %%
def get_hull_area(gdf):
    """Get area of each convex hull and return pandas.Series
    
    Parameters
    ----------
    gdf : GeoDataFrame
    
    Returns
    -------
    pandas.Series
    """
    
    hulls = gdf.convex_hull
    return hulls.area

# %%
world_ddf['hull_area'] = world_ddf.map_partitions(get_hull_area)

# %%
world_ddf.compute()
# Out:
#          pop_est      continent                      name iso_a3  gdp_md_est  \
# 0       889953.0        Oceania                      Fiji    FJI        5496
# 1     58005463.0         Africa                  Tanzania    TZA       63177
# 2       603253.0         Africa                 W. Sahara    ESH         907
# 3     37589262.0  North America                    Canada    CAN     1736425
# 4    328239523.0  North America  United States of America    USA    21433226
# ..           ...            ...                       ...    ...         ...
# 172    6944975.0         Europe                    Serbia    SRB       51475
# 173     622137.0         Europe                Montenegro    MNE        5542
# 174    1794248.0         Europe                    Kosovo    KOS        7926
# 175    1394973.0  North America       Trinidad and Tobago    TTO       24269
# 176   11062113.0         Africa                  S. Sudan    SSD       11998
#
#                                               geometry  \
# 0    MULTIPOLYGON (((20037508.343 -1812498.413, 200...
# 1    POLYGON ((3774143.866 -105758.362, 3792946.708...
# 2    POLYGON ((-964649.018 3205725.605, -964597.245...
# 3    MULTIPOLYGON (((-13674486.249 6274861.394, -13...
# 4    MULTIPOLYGON (((-13674486.249 6274861.394, -13...
# ..                                                 ...
# 172  POLYGON ((2096126.508 5765757.958, 2096127.988...
# 173  POLYGON ((2234260.104 5249565.284, 2204305.520...
# 174  POLYGON ((2292095.761 5139344.949, 2284604.344...
# 175  POLYGON ((-6866186.192 1204901.071, -6802177.4...
# 176  POLYGON ((3432408.751 390883.649, 3334408.389 ...
#
#                                            convex_hull     hull_area
# 0    POLYGON ((19807373.107 -2071284.965, -20037508...  6.432272e+12
# 1    POLYGON ((4064728.977 -1313965.660, 3847200.38...  1.059699e+12
# 2    POLYGON ((-1899491.585 2391849.029, -1894705.4...  3.139454e+11
# 3    POLYGON ((-9205018.632 5112435.324, -13805051....  9.127826e+13
# 4    POLYGON ((-17331127.807 2145071.126, -17358788...  7.099766e+13
# ..                                                 ...           ...
# 172  POLYGON ((2401900.131 5197783.944, 2255063.490...  1.891208e+11
# 173  POLYGON ((2156455.368 5142654.741, 2133155.290...  2.998349e+10
# 174  POLYGON ((2306240.400 5138104.706, 2292095.761...  2.435674e+10
# 175  POLYGON ((-6876204.946 1118889.975, -6896242.4...  8.808172e+09
# 176  POLYGON ((3432408.751 390883.649, 3114716.820 ...  8.237935e+11
#
# [176 rows x 8 columns]

# %% [markdown]
# The task graph now includes the `assign` step, assigning the new column to the dataframe.

# %%
world_ddf.visualize()

# %% [markdown]
# ### Specifying meta-data
#
# To build a task graph, Dask doesn't need to see the data. But it needs to understand their general structure and dtypes. With simple `map_partitions` cases, you don't need to worry about that as Dask is often able to figure that out itself. But sometimes it struggles.
#
# Let's look a bit under the hood here.

# %%
world_ddf = dask_geopandas.read_parquet("data/world/")

# %% [markdown]
# Each object contains its `_meta` data. For GeoDataFrame, that is usually an empty frame with columns and their dtypes set. Like this one:

# %%
world_ddf._meta
# Out:
# Empty GeoDataFrame
# Columns: [pop_est, continent, name, iso_a3, gdp_md_est, geometry, convex_hull]
# Index: []

# %% [markdown]
# You can see that all dtypes are set.

# %%
world_ddf._meta.dtypes
# Out:
# pop_est           int64
# continent        object
# name             object
# iso_a3           object
# gdp_md_est      float64
# geometry       geometry
# convex_hull    geometry
# dtype: object

# %% [markdown]
# Now, we can try to implement our own version of `dissolve` that works well when all data fit in memory, to make the exmaple a bit more complicated. We need two steps:
#
# 1. Shuffle the data into partitions based on the `continent` column. That ensures that all observations from the same continent are within a single partition.
# 2. Use `map_partitions` to apply `dissolve` from geopandas.
#
# We can use the `shuffle` method to do the first step. Note that this is also a form of spatial partitioning and it may be useful to follow the attribute if you have one and the final partitions are of a roughly the same size.

# %%
shuffled = world_ddf.shuffle(
    "continent", npartitions=7, ignore_index=True
)

# %%
shuffled.calculate_spatial_partitions()
shuffled.spatial_partitions.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e22fc7fe8b2a7bac1a56a493cad62d1d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e22fc7fe8b2a7bac1a56a493cad62d1d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_e22fc7fe8b2a7bac1a56a493cad62d1d = L.map(
#                 &quot;map_e22fc7fe8b2a7bac1a56a493cad62d1d&quot;,
#                 {
#                     center: [14.01665000000001, 1.4210854715202004e-14],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_e22fc7fe8b2a7bac1a56a493cad62d1d);
#
#
#
#
#
#             var tile_layer_9c5f0d7ec38193cf11be836ba3868461 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e22fc7fe8b2a7bac1a56a493cad62d1d);
#
#
#             map_e22fc7fe8b2a7bac1a56a493cad62d1d.fitBounds(
#                 [[-55.61182999999999, -180.0], [83.64513000000001, 180.00000000000003]],
#                 {}
#             );
#
#
#         function geo_json_54d77793386c1f76e94397e11a5446c9_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_54d77793386c1f76e94397e11a5446c9_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_54d77793386c1f76e94397e11a5446c9_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_54d77793386c1f76e94397e11a5446c9_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_54d77793386c1f76e94397e11a5446c9_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_54d77793386c1f76e94397e11a5446c9.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_54d77793386c1f76e94397e11a5446c9_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_54d77793386c1f76e94397e11a5446c9 = L.geoJson(null, {
#                 onEachFeature: geo_json_54d77793386c1f76e94397e11a5446c9_onEachFeature,
#
#                 style: geo_json_54d77793386c1f76e94397e11a5446c9_styler,
#                 pointToLayer: geo_json_54d77793386c1f76e94397e11a5446c9_pointToLayer
#         });
#
#         function geo_json_54d77793386c1f76e94397e11a5446c9_add (data) {
#             geo_json_54d77793386c1f76e94397e11a5446c9
#                 .addData(data)
#                 .addTo(map_e22fc7fe8b2a7bac1a56a493cad62d1d);
#         }
#             geo_json_54d77793386c1f76e94397e11a5446c9_add({&quot;bbox&quot;: [-180.0, -55.61182999999999, 180.00000000000003, 83.64513000000001], &quot;features&quot;: [{&quot;bbox&quot;: [-17.625042690490655, -34.819166355123706, 51.133869999999995, 37.34999441176655], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[19.616405063564567, -34.819166355123706], [18.85531456876987, -34.444305515278465], [18.37741092293461, -34.13652068454807], [-16.61383826340328, 12.170911159712702], [-17.625042690490655, 14.729540513564075], [-17.06342322434257, 20.999752102130824], [-17.020428432675768, 21.422310288981574], [-16.973247849993246, 21.885744533774982], [-15.982610642958035, 23.723358466074046], [-14.439939947964831, 26.254418443297652], [-9.300692918321886, 32.56467926689067], [-8.65747636558501, 33.240245266242425], [-5.929994269219889, 35.75998810479398], [1.4669185726065448, 36.605647081034405], [6.261819695672612, 37.11065501560674], [9.509993523810607, 37.34999441176655], [11.028867221733348, 37.09210317641396], [34.265440000000005, 31.219359999999988], [51.11119999999999, 12.024640000000002], [51.133869999999995, 11.74815], [50.47653689962553, -15.226512139550545], [50.37711144389595, -15.70606943121913], [47.5477234230513, -23.781958916928517], [47.095761346226595, -24.941629733990453], [25.780628289500697, -33.94464609144834], [20.07126102059763, -34.79513

# %% [markdown]
# Sometimes the inference of the meta DataFrame just fails, mostly because it is empty. If that happens, you can manually specify the meta data data frame and pass it to the `map_partitions`. Even if it does not fail, like in this case, it is often better to directly pass it as it can be chaper and you avoid potential issues that may come as a result of a wrong inference.

# %%
meta = world_ddf._meta.dissolve(by="continent", as_index=False)
meta
# Out:
# Empty GeoDataFrame
# Columns: [continent, geometry, pop_est, name, iso_a3, gdp_md_est, convex_hull]
# Index: []

# %% [markdown]
# With the `meta` defined, we can take the `geopandas.GeoDataFrame.dissolve` method and pass it to `map_partitions`. All `**kwargs` are passed as attributes to the method/function you are applying.

# %%
dissolved = shuffled.map_partitions(
    geopandas.GeoDataFrame.dissolve, by="continent", as_index=False, meta=meta
)

# %%
dissolved.visualize()

# %%
dissolved.compute()
# Out:
#                  continent                                           geometry  \
# 0                   Africa  MULTIPOLYGON (((-11.43878 6.78592, -11.70819 6...
# 0                  Oceania  MULTIPOLYGON (((147.91405 -43.21152, 147.56456...
# 0                   Europe  MULTIPOLYGON (((-53.55484 2.33490, -53.77852 2...
# 1  Seven seas (open ocean)  POLYGON ((68.93500 -48.62500, 69.58000 -48.940...
# 0            North America  MULTIPOLYGON (((-155.22217 19.23972, -155.5421...
# 0            South America  MULTIPOLYGON (((-68.63999 -55.58002, -69.23210...
# 0                     Asia  MULTIPOLYGON (((48.67923 14.00320, 48.23895 13...
#
#      pop_est                    name iso_a3  gdp_md_est  \
# 0   53950935                Tanzania    TZA    150600.0
# 0     920938                    Fiji    FJI      8374.0
# 0  142257519                  Russia    RUS   3745000.0
# 1        140  Fr. S. Antarctic Lands    ATF        16.0
# 0   35623680                  Canada    CAN   1674000.0
# 0   44293293               Argentina    ARG    879400.0
# 0   18556698              Kazakhstan    KAZ    460700.0
#
#                                          convex_hull
# 0  POLYGON ((4064728.977 -1313965.660, 3847200.38...
# 0  POLYGON ((19807373.107 -2071284.965, -20037508...
# 0  POLYGON ((5322815.560 5034701.226, -19357551.0...
# 1  POLYGON ((7652658.395 -6407400.602, 7649875.40...
# 0  POLYGON ((-9205018.632 5112435.324, -13805051....
# 0  POLYGON ((-7397180.163 -7410537.977, -7640229....
# 0  POLYGON ((7598656.850 4962661.474, 6173250.313...

# %% [markdown]
# When you are done, you can shut down the Dask client. If you want to do the exercises below, do not do that yet.

# %%
client.shutdown()
# Out:
# 2022-06-22 12:36:26,670 - distributed.client - ERROR - Failed to reconnect to scheduler after 30.00 seconds, closing client

# %% [markdown]
# ## Limits and caveats
#
# Truth to be told, we are now playing with the version 0.1 of dask-geopandas and not everything is as polished as we would like it to be. So there are some things which are not yet fully supported.
#
# - **Overlapping computation** - With `dask.dataframe` and `dask.array` you can use `map_overlap` to do some overlapping computations for which you need observations from neighbouring partitions. With dask-geopandas, we would need this overlap to be spatial and that is not yet supported. That means that whatever depends on topology or similar operation is currently not very easy to parallelise.
# - **Spatial indexing** - While you can use spatial indexing over spatial partitions and then within individual partitions as we use it under the hood in `sjoin`, it requires a bit of low-level dask code to make it correctly run. We hope to make that easier at some point in the future. We also want to expand the use of the spatial partitioning information to more methods (currently only `sjoin` makes use of it).
# - **Memory management** - Even though Dask can work out-of-core and you may seem dask-geopadnas behaving that way sometimes, we still have some unresolved memory issues due to geometries being stored as C objects, hence their actual size is not directly visible to Dask.
#
# There are also the same, or at least very similar, rules when not to use dask-geopandas as they apply to vanilla dask.dataframe (from [Dask documentation](https://docs.dask.org/en/stable/dataframe-best-practices.html)):
#
# - For data that fits into RAM, geopandas can often be faster and easier to use than Dask. While “Big Data” tools can be exciting, they are almost always worse than normal data tools while those remain appropriate. But for embarrasinlgy parallel computation, it will often bring speedup with minimal overhead.
# - Similar to above, even if you have a large dataset there may be a point in your computation where you’ve reduced things to a more manageable level. You may want to switch to (geo)pandas at this point.
#
# ```
# df = dd.read_parquet('my-giant-file.parquet')
# df = df[df.name == 'Alice']              # Select a subsection
# result = df.groupby('id').value.mean()   # Reduce to a smaller size
# result = result.compute()                # Convert to pandas dataframe
# result...                                # Continue working with pandas
# ```
#
# - Usual pandas and GeoPandas performance tips like avoiding apply, using vectorized operations, using categoricals, etc., all apply equally to Dask DataFrame and dask-geopandas.
#
# See more best practices in the [Dask documentation](https://docs.dask.org/en/stable/dataframe-best-practices.html).

# %% [markdown]
# ## Exercises
#
# Use the `data/airports_csv` folder and try to do the following using Dask:
#
# - Read the contents as a `dask.dataframe`
# - Create a valid `dask_geopandas.GeoDataFrame`
# - Calculate and explore spatial partitions. If you think there's a need to spatially shuffle the data, do so.
#     - Try comparing different sorting methods (check the docs!). Which one is the best an why?
# - How many airports are there per continent? And how many per country?
# - Are there any points not falling onto ground? How many?
# - Where would be the ideal single airport in each country if you had to build only one?
